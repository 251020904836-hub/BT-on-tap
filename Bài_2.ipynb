# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904836-hub/BT-on-tap/blob/main/B%C3%A0i_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số nguyên dương n: "))
tong = 0

for i in range(1, n + 1):
    if i % 2 == 0:
        tong += i

print("Tổng các số chẵn từ 1 đến", n, "là:", tong)
# Out:
# Nhập số nguyên dương n: 6
# Tổng các số chẵn từ 1 đến 6 là: 12
